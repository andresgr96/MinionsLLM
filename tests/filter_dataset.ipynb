# %%
import argparse
import json
import pandas as pd
from vi import Config, Window
from simulation.envs.robot_env import RobotEnvironment
from pathlib import Path
import tempfile
import time
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def run_tree(bt_string: str) -> dict:
    """Run a single behavior tree and return its metrics"""
    # Create a temporary file to store the tree
    with tempfile.NamedTemporaryFile(mode='w', suffix='.xml', delete=False) as tmp:
        tmp.write(bt_string)
        tmp_path = tmp.name

    # Setup and run simulation
    config = Config(radius=25, visualise_chunks=True, window=Window.square(500), 
                   movement_speed=1, duration=1000)
    environment = RobotEnvironment(config=config, bt_path=tmp_path, 
                                 n_agents=10, n_parts=15, task="any", headless=True)
    environment.setup()
    metrics = environment.run()
    # print(metrics)
    
    # Clean up temp file
    Path(tmp_path).unlink()
    
    return metrics

def process_dataset(input_path: str, n_trees: int) -> pd.DataFrame:
    """Process n_trees from the dataset and collect their metrics"""
    # Load dataset
    with open(input_path, 'r') as f:
        dataset = json.load(f)
    

    # Initialize results dataframe and timing tracking
    results = []
    tree_times = []
    start_time = time.time()
    
    # Process trees
    total_trees = min(n_trees, len(dataset))
    for i in range(total_trees):
        tree_start = time.time()
        tree_data = dataset[i]
        
        try:
            # Run the tree and get metrics
            metrics = run_tree(tree_data['tree'])
            
            # Add tree index and metrics to results
            result = {'tree_index': i}
            result.update(metrics)
            results.append(result)
            
            # Track time for this tree
            tree_time = time.time() - tree_start
            tree_times.append(tree_time)
            if len(tree_times) > 25:
                tree_times.pop(0)
            
            # Every 25 trees, print timing estimate
            if (i + 1) % 25 == 0 or i == 0:
                elapsed_time = (time.time() - start_time) / 60
                avg_time_per_tree = sum(tree_times) / len(tree_times)
                trees_remaining = total_trees - (i + 1)
                estimated_time_remaining = (avg_time_per_tree * trees_remaining) / 60
                
                print(f"Trees Processed: {i+1}/{total_trees} - "
                      f"Time Elapsed: {elapsed_time:.1f}m - "
                      f"Remaining Time: {estimated_time_remaining:.1f}m")
            
        except Exception as e:
            print(f"Error processing tree {i}: {str(e)}")
            continue
    
    # Convert results to DataFrame
    return pd.DataFrame(results)

# %%
dataset_path = "./data_generation_grammar/datasets/enriched_dataset_b_v2.json"
n_trees = 6000
print(f"Processing {n_trees} trees from {dataset_path}")
# Process the trees and get metrics
results_df = process_dataset(dataset_path, n_trees)

# Print summary statistics
print("\nMetrics Summary:")
print(results_df.describe())
# Out:
# Processing 6000 trees from ./data_generation_grammar/datasets/enriched_dataset_b_v2.json
# Trees Processed: 1/2000 - Time Elapsed: 0.0m - Remaining Time: 18.2m
# Trees Processed: 25/2000 - Time Elapsed: 0.2m - Remaining Time: 17.9m
# Trees Processed: 50/2000 - Time Elapsed: 0.4m - Remaining Time: 14.6m
# Trees Processed: 75/2000 - Time Elapsed: 0.6m - Remaining Time: 15.0m
# Trees Processed: 100/2000 - Time Elapsed: 0.8m - Remaining Time: 14.5m
# Trees Processed: 125/2000 - Time Elapsed: 1.0m - Remaining Time: 14.6m
# Trees Processed: 150/2000 - Time Elapsed: 1.2m - Remaining Time: 14.1m
# Trees Processed: 175/2000 - Time Elapsed: 1.4m - Remaining Time: 14.1m
# Trees Processed: 200/2000 - Time Elapsed: 1.6m - Remaining Time: 13.8m
# Trees Processed: 225/2000 - Time Elapsed: 1.8m - Remaining Time: 13.3m
# Trees Processed: 250/2000 - Time Elapsed: 1.9m - Remaining Time: 13.5m
# Trees Processed: 275/2000 - Time Elapsed: 2.1m - Remaining Time: 13.5m
# Trees Processed: 300/2000 - Time Elapsed: 2.3m - Remaining Time: 13.4m
# Trees Processed: 325/2000 - Time Elapsed: 2.5m - Remaining Time: 13.3m
# Trees Processed: 350/2000 - Time Elapsed: 2.7m - Remaining Time: 12.6m
# Trees Processed: 375/2000 - Time Elapsed: 2.9m - Remaining Time: 13.7m
# Trees Processed: 400/2000 - Time Elapsed: 3.1m - Remaining Time: 12.9m
# Trees Processed: 425/2000 - Time Elapsed: 3.4m - Remaining Time: 13.3m
# Trees Processed: 450/2000 - Time Elapsed: 3.6m - Remaining Time: 12.8m
# Trees Processed: 475/2000 - Time Elapsed: 3.8m - Remaining Time: 12.3m
# Trees Processed: 500/2000 - Time Elapsed: 4.0m - Remaining Time: 11.8m
# Trees Processed: 525/2000 - Time Elapsed: 4.2m - Remaining Time: 11.3m
# Trees Processed: 550/2000 - Time Elapsed: 4.4m - Remaining Time: 11.6m
# Trees Processed: 575/2000 - Time Elapsed: 4.6m - Remaining Time: 11.7m
# Trees Processed: 600/2000 - Time Elapsed: 4.8m - Remaining Time: 10.8m
# Trees Processed: 625/2000 - Time Elapsed: 5.0m - Remaining Time: 11.5m
# Trees Processed: 650/2000 - Time Elapsed: 5.2m - Remaining Time: 10.7m
# Trees Processed: 675/2000 - Time Elapsed: 5.4m - Remaining Time: 10.6m
# Trees Processed: 700/2000 - Time Elapsed: 5.6m - Remaining Time: 10.3m
# Trees Processed: 725/2000 - Time Elapsed: 5.8m - Remaining Time: 10.4m
# Trees Processed: 750/2000 - Time Elapsed: 6.0m - Remaining Time: 10.1m
# Trees Processed: 775/2000 - Time Elapsed: 6.2m - Remaining Time: 9.9m
# Trees Processed: 800/2000 - Time Elapsed: 6.4m - Remaining Time: 9.8m
# Trees Processed: 825/2000 - Time Elapsed: 6.6m - Remaining Time: 9.2m
# Trees Processed: 850/2000 - Time Elapsed: 6.8m - Remaining Time: 9.2m
# Trees Processed: 875/2000 - Time Elapsed: 7.0m - Remaining Time: 9.1m
# Trees Processed: 900/2000 - Time Elapsed: 7.2m - Remaining Time: 8.7m
# Trees Processed: 925/2000 - Time Elapsed: 7.4m - Remaining Time: 9.0m
# Trees Processed: 950/2000 - Time Elapsed: 7.6m - Remaining Time: 8.3m
# Trees Processed: 975/2000 - Time Elapsed: 7.8m - Remaining Time: 8.0m
# Trees Processed: 1000/2000 - Time Elapsed: 8.0m - Remaining Time: 7.8m
# Trees Processed: 1025/2000 - Time Elapsed: 8.2m - Remaining Time: 7.8m
# Trees Processed: 1050/2000 - Time Elapsed: 8.4m - Remaining Time: 7.4m
# Trees Processed: 1075/2000 - Time Elapsed: 8.6m - Remaining Time: 7.6m
# Trees Processed: 1100/2000 - Time Elapsed: 8.8m - Remaining Time: 7.4m
# Trees Processed: 1125/2000 - Time Elapsed: 9.0m - Remaining Time: 6.8m
# Trees Processed: 1150/2000 - Time Elapsed: 9.2m - Remaining Time: 7.0m
# Trees Processed: 1175/2000 - Time Elapsed: 9.4m - Remaining Time: 6.4m
# Trees Processed: 1200/2000 - Time Elapsed: 9.6m - Remaining Time: 6.2m
# Trees Processed: 1225/2000 - Time Elapsed: 9.8m - Remaining Time: 6.0m
# Trees Processed: 1250/2000 - Time Elapsed: 9.9m - Remaining Time: 5.9m
# Trees Processed: 1275/2000 - Time Elapsed: 10.2m - Remaining Time: 5.8m
# Trees Processed: 1300/2000 - Time Elapsed: 10.3m - Remaining Time: 5.5m
# Trees Processed: 1325/2000 - Time Elapsed: 10.5m - Remaining Time: 5.4m
# Trees Processed: 1350/2000 - Time Elapsed: 10.7m - Remaining Time: 5.2m
# Trees Processed: 1375/2000 - Time Elapsed: 10.9m - Remaining Time: 5.0m
# Trees Processed: 1400/2000 - Time Elapsed: 11.1m - Remaining Time: 4.8m
# Trees Processed: 1425/2000 - Time Elapsed: 11.3m - Remaining Time: 4.6m
# Trees Processed: 1450/2000 - Time Elapsed: 11.5m - Remaining Time: 4.4m
# Trees Processed: 1475/2000 - Time Elapsed: 11.7m - Remaining Time: 4.2m
# Trees Processed: 1500/2000 - Time Elapsed: 11.9m - Remaining Time: 3.9m
# Trees Processed: 1525/2000 - Time Elapsed: 12.2m - Remaining Time: 4.0m
# Trees Processed: 1550/2000 - Time Elapsed: 12.3m - Remaining Time: 3.5m
# Trees Processed: 1575/2000 - Time Elapsed: 12.5m - Remaining Time: 3.3m
# Trees Processed: 1600/2000 - Time Elapsed: 12.7m - Remaining Time: 3.3m
# Trees Processed: 1625/2000 - Time Elapsed: 12.9m - Remaining Time: 3.0m
# Trees Processed: 1650/2000 - Time Elapsed: 13.1m - Remaining Time: 2.7m
# Trees Processed: 1675/2000 - Time Elapsed: 13.3m - Remaining Time: 2.6m
# Trees Processed: 1700/2000 - Time Elapsed: 13.5m - Remaining Time: 2.4m
# Trees Processed: 1725/2000 - Time Elapsed: 13.7m - Remaining Time: 2.2m
# Trees Processed: 1750/2000 - Time Elapsed: 13.9m - Remaining Time: 2.0m
# Trees Processed: 1775/2000 - Time Elapsed: 14.1m - Remaining Time: 1.8m
# Trees Processed: 1800/2000 - Time Elapsed: 14.3m - Remaining Time: 1.6m
# Trees Processed: 1825/2000 - Time Elapsed: 14.5m - Remaining Time: 1.4m
# Trees Processed: 1850/2000 - Time Elapsed: 14.7m - Remaining Time: 1.2m
# Trees Processed: 1875/2000 - Time Elapsed: 14.9m - Remaining Time: 1.0m
# Trees Processed: 1900/2000 - Time Elapsed: 15.1m - Remaining Time: 0.8m
# Trees Processed: 1925/2000 - Time Elapsed: 15.3m - Remaining Time: 0.6m
# Trees Processed: 1950/2000 - Time Elapsed: 15.5m - Remaining Time: 0.4m
# Trees Processed: 1975/2000 - Time Elapsed: 15.7m - Remaining Time: 0.2m
# Trees Processed: 2000/2000 - Time Elapsed: 15.9m - Remaining Time: 0.0m
#
# Metrics Summary:
#         tree_index  total_parts_placed  good_parts_correctly_placed  \
# count  2000.000000         2000.000000                  2000.000000
# mean    999.500000            0.035500                     0.030000
# std     577.494589            0.774945                     0.670317
# min       0.000000            0.000000                     0.000000
# 25%     499.750000            0.000000                     0.000000
# 50%     999.500000            0.000000                     0.000000
# 75%    1499.250000            0.000000                     0.000000
# max    1999.000000           19.000000                    15.000000
#
#        bad_parts_correctly_placed  good_parts_picked_up  bad_parts_picked_up  \
# count                 2000.000000           2000.000000          2000.000000
# mean                     0.001000              0.167500             0.167000
# std                      0.044721              1.374186             0.877209
# min                      0.000000              0.000000             0.000000
# 25%                      0.000000              0.000000             0.000000
# 50%                      0.000000              0.000000             0.000000
# 75%                      0.000000              0.000000             0.000000
# max                      2.000000             19.000000            10.000000
#
#        nest_integrity
# count     2000.000000
# mean         0.200000
# std          4.468779
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        100.000000

# %%
# Save results to CSV
output_path = "dataset_b_v2_metrics.csv"
results_df.to_csv(output_path, index=False)
print(f"Results saved to {output_path}")
# Out:
# Results saved to dataset_b_v2_metrics.csv

# %%
results_df.head()
# Out:
#    tree_index  total_parts_placed  good_parts_correctly_placed  \
# 0           0                  15                           15
# 1           1                  19                           15
# 2           2                   0                            0
# 3           3                   0                            0
# 4           4                   0                            0
#
#    bad_parts_correctly_placed  good_parts_picked_up  bad_parts_picked_up  \
# 0                           0                    15                    5
# 1                           0                    19                    0
# 2                           0                     6                    9
# 3                           0                     7                   10
# 4                           0                     6                    9
#
#    nest_integrity
# 0             100
# 1             100
# 2               0
# 3               0
# 4               0

# %%
print(f"Total Trees: {len(results_df)}")

# Get the number of trees that succesfully picked up a good part
n_good_pickups = len(results_df[results_df['good_parts_picked_up'] > 0])
print(f"Trees that picked up good parts: {n_good_pickups}")

# Get the number of trees that succesfully picked up a scrap part
n_bad_pickups = len(results_df[results_df['bad_parts_picked_up'] > 0]) 
print(f"Trees that picked up scrap parts: {n_bad_pickups}")

# Get the number of trees that succesfully placed a good part correctly
n_good_placed = len(results_df[results_df['good_parts_correctly_placed'] > 0])
print(f"Trees that correctly placed good parts: {n_good_placed}")

# Get the number of trees that succesfully placed a scrap part correctly
n_bad_placed = len(results_df[results_df['bad_parts_correctly_placed'] > 0])
print(f"Trees that correctly placed scrap parts: {n_bad_placed}")
# Out:
# Total Trees: 2000
# Trees that picked up good parts: 35
# Trees that picked up scrap parts: 91
# Trees that correctly placed good parts: 4
# Trees that correctly placed scrap parts: 1
